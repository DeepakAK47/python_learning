# %%
print("My name is Deepak Singh")
# Out:
# My name is Deepak Singh

# %% [markdown]
# ### python is a case sensitive language

# %% [raw]
# Use of seperator keyword

# %%
print("Deepak Singh",4.4,'qw23',sep=',')
# Out:
# Deepak Singh,4.4,qw23

# %%
print("Deepak Singh",end='-')
print("Vinay Singh")
# Out:
# Deepak Singh-Vinay Singh

# %% [markdown]
# # Data types

# %%
# maximum integer value taht python can handle
print(1e308)
# Out:
# 1e+308

# %%
print(1e309)
# Out:
# inf

# %%
# maximum range of the float value that python can handle 
print(1.7e308)
# Out:
# 1.7e+308

# %%
print(1.7e309)
# Out:
# inf

# %% [markdown]
# ### boolean is not text

# %%
# boolean 
print(True)
# Out:
# True

# %%
print(False)
# Out:
# False

# %% [markdown]
# ### python do not have char data type

# %% [markdown]
# ### In python we use list as array

# %% [markdown]
# # List

# %%
# List
print([1,2,3,4,5,6])
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# Tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#set
print({1,2,3,4,5,6})
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
#Disctionary
print({
    'name': 'Deepak Singh',
    'class' : 'AIDS',
    'Roll number' : 49
      })
# Out:
# {'name': 'Deepak Singh', 'class': 'AIDS', 'Roll number': 49}

# %% [markdown]
# # type funciton

# %%
name = "Deepak Singh"
print(type(name))
# Out:
# <class 'str'>

# %%
type(78)
# Out:
# int

# %%
type("123dfg")
# Out:
# str

# %% [markdown]
# ### Stylize way of declaring value of the variables

# %%
a,b,c = 1,2,3

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
c
# Out:
# 3

# %%
print(a,b,c)
# Out:
# 1 2 3

# %% [markdown]
# #Keyword and identifiers

# %% [markdown]
# ### Compilation is the process of conversion of the code into 0 1

# %% [markdown]
# ### Keyword are the variable which is reserved for the programming languages

# %% [markdown]
# ### Idenditifies as same assigning the name to any variable.

# %%
#Take the input from the user and prints itsvalue
a = int(input("Enter the first number : "))
b = int(input("Enter the second number : "))
print("The sum a and b is : ",a+b)
# Out:
# Enter the first number :  10
# Enter the second number :  20
# The sum a and b is :  30
