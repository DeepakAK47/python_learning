# %% [raw]
# Write OOP classes to handle the following scenarios:
# A user can create and view 2D coordinates
# A user can find out the distance between 2 coordinates
# A user can find find the distance of a coordinate from origin
# A user can check if a point lies on a given line
# A user can find the distance between a given 2D point and a given line

# %%
class Point:
    def __init__(self,x,y):
        self.x_cod = x
        self.y_cod = y
    def __str__(self):
        return '<{},{}>'.format(self.x_cod,self.y_cod)

    # distance method
    def euclidian_diatance(self,other):
        return (( (self.x_cod - other.x_cod)**2 + (self.y_cod-other.y_cod)**2 )**0.5)

# %%
p1 = Point(1,2)
p2 = Point(3,5)
p3 = Point(0,0)

# %%
print(p1)
# Out:
# <1,2>

# %%
// doubt
# Out:
#   Cell In[4], line 1
#     // doubt
#     ^
# SyntaxError: invalid syntax

# %%
p1.euclidian_diatance(p2)
# Out:
# 3.605551275463989

# %%
p1.euclidian_diatance(p3)
# Out:
# 2.23606797749979

# %% [markdown]
# # line class

# %%
class Line:
    def __init__(self,A,B,C):
        self.x_coff = A
        self.y_coff = B
        self.c_coff = C
    # method for priting line equation
    def __str__(self): # Note __str__() magic method does not required any arguments other than self
        return '{}x + {}y + {} = 0'.format(self.x_coff,self.y_coff,self.c_coff)

    # method check point lies on equ
    def check(line,point):
        if line.x_coff*point.x_cod + line.y_coff*point.y_cod + line.c_coff == 0:
            return 'point lies on the line'
        else:
            return 'point does not lie on the line'

    # sortest path method
    def sort_path(line,point):
        num = line.x_coff*point.x_cod + line.y_coff*point.y_cod + line.c_coff
        den = (line.x_coff*line.x_coff + line.y_coff*line.y_coff)**0.5
        ans = num/den
        if(ans < 0):
            return -1*ans

        else:
            return ans

# %%
l1  = Line(1,2,3)

# %%
l1

# %%
print(l1)
# Out:
# 1x + 2y + 3 = 0

# %%
p3 = Point(-1,-1)

# %%
l1.check(p3)
# Out:
# 'point lies on the line'

# %% [markdown]
# # Sortest path

# %%
l1.sort_path(p1)
# Out:
# 3.5777087639996634

# %% [markdown]
# # attribution creation from outside the class

# %%
# adding new attribute from outside the method
class Person:
    def __init__(self,name,country):
        self.name = name
        self.country = country

    # salutation method
    def salutation(self):
        if self.country=='india':
            print('Namaste',self.name)

        else:
                print('Hello ',self.name)

# %%
p1 = Person('Deepak','india')

# %%
print(p1)

# %%
p1.salutation()
# Out:
# Namaste Deepak

# %%
p2 = Person('Kinjal','UK')

# %%
p2.salutation()
# Out:
# Hello  Kinjal

# %%
p1.gender()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 p1.gender()
#
# AttributeError: 'Person' object has no attribute 'gender'

# %% [markdown]
# # doubt

# %%
p1.geander = 'male'

# %%
p1.gender
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 p1.gender
#
# AttributeError: 'Person' object has no attribute 'gender'

# %% [markdown]
# # Reference variable

# %%
# adding new attribute from outside the method
class Person:
    def __init__(self,name,country):
        self.name = name
        self.country = country

    # salutation method
    def salutation(self):
        if self.country=='india':
            print('Namaste',self.name)

        else:
                print('Hello ',self.name)
p =  Person('kinjal','india')

# %%
print(p.name)
# Out:
# kinjal

# %%
p.country
# Out:
# 'india'

# %%
# object without a reference
class Person:

  def __init__(self):
    self.name = 'nitish'
    self.gender = 'male'

p = Person()
q = p

# %%
p.name
# Out:
# 'nitish'

# %%
p.gender
# Out:
# 'male'

# %%
q.name
# Out:
# 'nitish'

# %%
q.gender
# Out:
# 'male'

# %%
print(id(p))
print(id(q))
# Out:
# 2376044162960
# 2376044162960

# %%
# pass by reference 
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

# outside the class -> function
def greet(person):
  print('Hi my name is',person.name,'and I am a',person.gender)
  p1 = Person('ankit','male')
  return p1

p = Person('nitish','male')
x = greet(p)
print(x.name)
print(x.gender)
# Out:
# Hi my name is nitish and I am a male
# ankit
# male

# %% [markdown]
# # Encapsulation

# %%
# create a class for ATM system using encapsulation technique

# %%
class Atm:

  # constructor(special function)->superpower -> 
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0
    #self.menu()

  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
    else:
      print('nai karne de sakta re baba')

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.__balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful.balance is',self.__balance)
      else:
        print('abe garib')
    else:
      print('sale chor')

# %%
p1 = ATM(1234,1000,9999)

# %%
p1.menu()
# Out:
#         hi how can I help you
#          1. Press 1 to create pin
#          2. Press 2 to change pin
#          3. Press 3 to check balance
#          4. Press 4 to withdraw
#          5. Anything else to exit
#          1

# %% [markdown]
# # collection of objects

# %%
class Person:
    def __init__(self,name,gender):
        self.name = name
        self.gender = gender

    def info(self):
         print('The name of candidate is : ',self.name)
         print('The gender is guy is : ',self.gender)

# %%
p1 = Person('Deepak','male')
p2 = Person('Kinjal Singh','Female')
p3 = Person('Aabhash','male')

# %%
L = [p1,p2,p3]

# %%
print(L)
# Out:
# [<__main__.Person object at 0x000001FE59823A80>, <__main__.Person object at 0x000001FE59823BB0>, <__main__.Person object at 0x000001FE598B5910>]

# %%
for i in L:
    print(i.name,i.gender)
# Out:
# Deepak male
# Kinjal Singh Female
# Aabhash male

# %%
d = {p1,p2,p3}

# %%
for i in d:
    print(i.name,i.gender)
# Out:
# Deepak male
# Aabhash male
# Kinjal Singh Female

# %% [markdown]
# # Static variable Vs instance variable

# %%
# instance variable is e like local variable. It is different from all the object while static
